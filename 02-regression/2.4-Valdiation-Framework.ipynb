# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df.columns = df.columns.str.lower().str.replace(" " , "_")

# %%
n  = len(df)
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = int(n * 0.6)

# %%
n , n_val+ n_test+ n_train
# because of rounding, the sum of the splits may not equal the total number of samples. To ensure that the sum of the splits equals the total number of samples, we can adjust the size of the training set to be equal to the total number of samples minus the sizes of the validation and test sets. This way, we can ensure that all samples are used in one of the splits.
# Out:
# (11914, 11912)

# %%
n_val = int(n * 0.2)
n_test = int(n * 0.2)
n_train = n - n_val - n_test

# %%
n , n_val+ n_test +  n_train
# Out:
# (11914, 11914)

# %%
n , n_val, n_test , n_train
# Out:
# (11914, 2382, 2382, 7150)

# %%
df.iloc[[0,1,2]]
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# 0  Factory Tuner,Luxury,High-Performance      Compact         Coupe
# 1                     Luxury,Performance      Compact   Convertible
# 2                Luxury,High-Performance      Compact         Coupe
#
#    highway_mpg  city_mpg  popularity   msrp
# 0           26        19        3916  46135
# ...

# %%
#if we want to take the first 10 records of the dataset, we can use the iloc method to select the first 10 rows of the dataframe. The iloc method allows us to select rows and columns by their integer index. In this case, we are selecting the first 10 rows (index 0 to 9) and all columns (indicated by the colon).
df.iloc[:10]
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
df.iloc[1]
# Out:
# make                                         BMW
# model                                   1 Series
# year                                        2011
# engine_fuel_type     premium unleaded (required)
# engine_hp                                  300.0
# engine_cylinders                             6.0
# transmission_type                         MANUAL
# driven_wheels                   rear wheel drive
# number_of_doors                              2.0
# market_category               Luxury,Performance
# vehicle_size                             Compact
# vehicle_style                        Convertible
# highway_mpg                                   28
# city_mpg                                      19
# popularity                                  3916
# msrp                                       40650
# Name: 1, dtype: object

# %%
df.iloc[0, 7]
# Out:
# 'rear wheel drive'

# %%
df.iloc[5:10]
# it will return the rows from index 5 to 9 (10 is exclusive) and all columns.
# Out:
#   make     model  year             engine_fuel_type  engine_hp  \
# 5  BMW  1 Series  2012  premium unleaded (required)      230.0
# 6  BMW  1 Series  2012  premium unleaded (required)      300.0
# 7  BMW  1 Series  2012  premium unleaded (required)      300.0
# 8  BMW  1 Series  2012  premium unleaded (required)      230.0
# 9  BMW  1 Series  2013  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 5               6.0            MANUAL  rear wheel drive              2.0
# 6               6.0            MANUAL  rear wheel drive              2.0
# 7               6.0            MANUAL  rear wheel drive              2.0
# 8               6.0            MANUAL  rear wheel drive              2.0
# 9               6.0            MANUAL  rear wheel drive              2.0
#
#            market_category vehicle_size vehicle_style  highway_mpg  city_mpg  \
# ...

# %%
df.iloc[:10]
# it will return the first 10 rows (index 0 to 9) and all columns.(from the beginning till 10 )
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
df.iloc[ n -4 :]
#it will return the last 4 rows of the dataframe. The iloc method allows us to select rows and columns by their integer index. In this case, we are using negative indexing to select the last 4 rows (index -4 to -1) and all columns (indicated by the colon).
# Out:
#           make   model  year                engine_fuel_type  engine_hp  \
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 11910               6.0         AUTOMATIC    all wheel drive              4.0
# 11911               6.0         AUTOMATIC    all wheel drive              4.0
# 11912               6.0         AUTOMATIC    all wheel drive              4.0
# 11913               6.0         AUTOMATIC  front wheel drive              4.0
#
#                   market_category vehicle_size  vehicle_style  highway_mpg  \
# 11910  Crossover,Hatchback,Luxury      Midsize  4dr Hatchback           23
# ...

# %%
df_val=df.iloc[ : n_val]
df_val
# Out:
#          make       model  year             engine_fuel_type  engine_hp  \
# 0         BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1         BMW    1 Series  2011  premium unleaded (required)      300.0
# 2         BMW    1 Series  2011  premium unleaded (required)      300.0
# 3         BMW    1 Series  2011  premium unleaded (required)      230.0
# 4         BMW    1 Series  2011  premium unleaded (required)      230.0
# ...       ...         ...   ...                          ...        ...
# 2377  Porsche     Cayenne  2016  premium unleaded (required)      570.0
# 2378  Porsche     Cayenne  2016                       diesel      240.0
# 2379  Porsche     Cayenne  2017  premium unleaded (required)      520.0
# 2380  Porsche     Cayenne  2017  premium unleaded (required)      300.0
# 2381  Porsche     Cayenne  2017  premium unleaded (required)      440.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %%
df_test = df.iloc [ n_val : n_val+n_test]
df_test
# Out:
#          make     model  year                engine_fuel_type  engine_hp  \
# 2382  Porsche   Cayenne  2017     premium unleaded (required)      570.0
# 2383  Porsche   Cayenne  2017     premium unleaded (required)      420.0
# 2384  Porsche  Cayman S  2006     premium unleaded (required)      295.0
# 2385  Porsche    Cayman  2014     premium unleaded (required)      275.0
# 2386  Porsche    Cayman  2014     premium unleaded (required)      325.0
# ...       ...       ...   ...                             ...        ...
# 4759     Ford      Flex  2016  premium unleaded (recommended)      365.0
# 4760     Ford      Flex  2016                regular unleaded      287.0
# 4761     Ford      Flex  2016                regular unleaded      287.0
# 4762     Ford      Flex  2016                regular unleaded      287.0
# 4763     Ford      Flex  2016                regular unleaded      287.0
#
#       engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# ...

# %%
df_train = df.iloc[ n_val+n_test : ]
# it means till the end of the dataframe
df_train
# Out:
#           make   model  year                engine_fuel_type  engine_hp  \
# 4764      Ford    Flex  2016                regular unleaded      287.0
# 4765      Ford    Flex  2017  premium unleaded (recommended)      365.0
# 4766      Ford    Flex  2017                regular unleaded      287.0
# 4767      Ford    Flex  2017                regular unleaded      287.0
# 4768      Ford    Flex  2017                regular unleaded      287.0
# ...        ...     ...   ...                             ...        ...
# 11909    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura     ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura     ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln  Zephyr  2006                regular unleaded      221.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# ...

# %%
# the we shuffle the data before splitting it into training, validation, and test sets. This is important to ensure that the data is randomly distributed and that the model is not biased towards any particular subset of the data. We can use the sample method to shuffle the data and reset the index to ensure that the index is sequential after shuffling.

# we can take numbers from 0 to n-1 and shuffle them. Then we can use these shuffled indices to select the rows from the dataframe. This way, we can ensure that the data is randomly distributed and that the model is not biased towards any particular subset of the data.

# %%
# we can write in this way too : 
df_train = df.iloc[: n_train]
df_val = df.iloc[ n_train : n_train + n_val]
df_test = df.iloc[n_train + n_val:]

# %%
n_train  , n_val , n_test
# Out:
# (7150, 2382, 2382)

# %%
df_train
# Out:
#          make       model  year             engine_fuel_type  engine_hp  \
# 0         BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1         BMW    1 Series  2011  premium unleaded (required)      300.0
# 2         BMW    1 Series  2011  premium unleaded (required)      300.0
# 3         BMW    1 Series  2011  premium unleaded (required)      230.0
# 4         BMW    1 Series  2011  premium unleaded (required)      230.0
# ...       ...         ...   ...                          ...        ...
# 7145    Mazda      Navajo  1994             regular unleaded      160.0
# 7146    Mazda      Navajo  1994             regular unleaded      160.0
# 7147  Lincoln   Navigator  2015             regular unleaded      365.0
# 7148  Lincoln   Navigator  2015             regular unleaded      365.0
# 7149  Lincoln   Navigator  2015             regular unleaded      365.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %%
idx =  np.arange(n)

# %%
df.iloc[ idx[:10]]
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
# 5  BMW    1 Series  2012  premium unleaded (required)      230.0
# 6  BMW    1 Series  2012  premium unleaded (required)      300.0
# 7  BMW    1 Series  2012  premium unleaded (required)      300.0
# 8  BMW    1 Series  2012  premium unleaded (required)      230.0
# 9  BMW    1 Series  2013  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# ...

# %%
np.random.seed(2)
np.random.shuffle(idx)

# %%
df.iloc[ idx[:10]]
# Out:
#              make            model  year             engine_fuel_type  \
# 2735    Chevrolet           Cobalt  2008             regular unleaded
# 6720       Toyota           Matrix  2012             regular unleaded
# 5878       Subaru          Impreza  2016             regular unleaded
# 11190  Volkswagen          Vanagon  1991             regular unleaded
# 4554         Ford            F-150  2017     flex-fuel (unleaded/E85)
# 8001   Volkswagen           Rabbit  2008             regular unleaded
# 2882      Bentley  Continental GTC  2013  premium unleaded (required)
# 649           BMW         6 Series  2015  premium unleaded (required)
# 616       Maybach               57  2012  premium unleaded (required)
# 4459         Ford   F-150 Heritage  2004             regular unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 2735       148.0               4.0            MANUAL  front wheel drive
# ...

# %%
idx[n_train :]
# Out:
# array([2779, 3708, 4794, ..., 6637, 2575, 7336], shape=(4764,))

# %%
df_train = df.iloc[idx[ : n_train]]
df_val = df.iloc[ idx[n_train : n_train + n_val]]
df_test = df.iloc[idx[n_train + n_val:]]

# %%
df.iloc[idx[ :10]]
# Out:
#              make            model  year             engine_fuel_type  \
# 2735    Chevrolet           Cobalt  2008             regular unleaded
# 6720       Toyota           Matrix  2012             regular unleaded
# 5878       Subaru          Impreza  2016             regular unleaded
# 11190  Volkswagen          Vanagon  1991             regular unleaded
# 4554         Ford            F-150  2017     flex-fuel (unleaded/E85)
# 8001   Volkswagen           Rabbit  2008             regular unleaded
# 2882      Bentley  Continental GTC  2013  premium unleaded (required)
# 649           BMW         6 Series  2015  premium unleaded (required)
# 616       Maybach               57  2012  premium unleaded (required)
# 4459         Ford   F-150 Heritage  2004             regular unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 2735       148.0               4.0            MANUAL  front wheel drive
# ...

# %%
df_train
# if you use random.seed(2) , it will always produce one particular sequence
# Out:
#               make        model  year                engine_fuel_type  \
# 2735     Chevrolet       Cobalt  2008                regular unleaded
# 6720        Toyota       Matrix  2012                regular unleaded
# 5878        Subaru      Impreza  2016                regular unleaded
# 11190   Volkswagen      Vanagon  1991                regular unleaded
# 4554          Ford        F-150  2017        flex-fuel (unleaded/E85)
# ...            ...          ...   ...                             ...
# 434            BMW     4 Series  2015     premium unleaded (required)
# 1902    Volkswagen       Beetle  2015  premium unleaded (recommended)
# 9334           GMC  Sierra 1500  2015        flex-fuel (unleaded/E85)
# 5284   Rolls-Royce        Ghost  2014     premium unleaded (required)
# 2420    Volkswagen           CC  2017  premium unleaded (recommended)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
len(df_train) , len( df_val)  , len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train
# Out:
#               make        model  year                engine_fuel_type  \
# 2735     Chevrolet       Cobalt  2008                regular unleaded
# 6720        Toyota       Matrix  2012                regular unleaded
# 5878        Subaru      Impreza  2016                regular unleaded
# 11190   Volkswagen      Vanagon  1991                regular unleaded
# 4554          Ford        F-150  2017        flex-fuel (unleaded/E85)
# ...            ...          ...   ...                             ...
# 434            BMW     4 Series  2015     premium unleaded (required)
# 1902    Volkswagen       Beetle  2015  premium unleaded (recommended)
# 9334           GMC  Sierra 1500  2015        flex-fuel (unleaded/E85)
# 5284   Rolls-Royce        Ghost  2014     premium unleaded (required)
# 2420    Volkswagen           CC  2017  premium unleaded (recommended)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train.reset_index()
# Out:
#       index         make        model  year                engine_fuel_type  \
# 0      2735    Chevrolet       Cobalt  2008                regular unleaded
# 1      6720       Toyota       Matrix  2012                regular unleaded
# 2      5878       Subaru      Impreza  2016                regular unleaded
# 3     11190   Volkswagen      Vanagon  1991                regular unleaded
# 4      4554         Ford        F-150  2017        flex-fuel (unleaded/E85)
# ...     ...          ...          ...   ...                             ...
# 7145    434          BMW     4 Series  2015     premium unleaded (required)
# 7146   1902   Volkswagen       Beetle  2015  premium unleaded (recommended)
# 7147   9334          GMC  Sierra 1500  2015        flex-fuel (unleaded/E85)
# 7148   5284  Rolls-Royce        Ghost  2014     premium unleaded (required)
# 7149   2420   Volkswagen           CC  2017  premium unleaded (recommended)
#
# ...

# %%
df_train  = df_train.reset_index(drop=True)
# drop true resets the index and throws away the old index
df_val  = df_val.reset_index(drop=True)
df_test  = df_test.reset_index(drop=True)

# %%
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
del df_train['msrp']
del df_val['msrp']
del df_test['msrp']

# %%
y_train
# Out:
# array([ 9.57574708,  9.887663  ,  9.89323518, ..., 10.45380308,
#        12.62248099, 10.54061978], shape=(7150,))
